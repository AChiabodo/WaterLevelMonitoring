# %%
import xarray as xr
import os
NDWI = '''..\\data\\NDWITemporal_256\\data'''
RGB = '''..\\data\\RGBTemporal\\data'''
TILE = 6
LAKE = "lake_nasser_4"
LAKENDWI = os.path.join(NDWI,LAKE,'tiles','tile_'+str(TILE))
features=xr.open_dataarray(os.path.join(LAKENDWI, 'features.nc'))
mask=xr.open_dataset(os.path.join(LAKENDWI, 'mask.nc'))
LAKERGB = os.path.join(RGB,LAKE,'tiles','tile_'+str(TILE))
try:
    rgb=xr.open_dataarray(os.path.join(LAKERGB, 'features.nc'))
except:
    rgb=None
water=xr.where(features>0.5, 1, 0)

# %%
features[0].plot.imshow(cmap="cividis")

# %%
features[3].plot.imshow(cmap="cividis")

# %%
(water[3]-water[0]).plot.imshow(cmap="cividis")

# %%
mask["water_change"].plot.imshow(cmap="cividis")

# %%
#rgb[[2,1,0],0].plot.imshow(vmax=4000) if rgb is not None else None

# %%
#rgb[[2,1,0],3].plot.imshow(vmax=4000) if rgb is not None else None

# %%
(features[3]-features[0]).plot.imshow(cmap="cividis")

# %%
difference = (features[3]-features[0])
difference = difference.where(abs(difference)>0.2)

# %%
import matplotlib.pyplot as plt
plt.imshow((features[0]-features[3]).values, cmap="cividis")
plt.imshow(mask["water_change"].values, cmap="RdGy", alpha=0.5)
plt.show()
